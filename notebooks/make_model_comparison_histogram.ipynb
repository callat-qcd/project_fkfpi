# %%
import numpy as np
import gvar as gv
import lsqfit
import sys
import os
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import h5py
import time

sys.path.append("../")
from fitter import data_loader as dl
from fitter import misc as ms

for j in range(10): # Sometimes this needs to be loaded twice...
    matplotlib.rcParams['figure.figsize'] = [10, 10]

# %%
reload(dl)
reload(ms)
# Out:
# <module 'fitter.misc' from '../fitter\misc.pyc'>

# %%
data_loader = dl.data_loader()
fit_results = data_loader.get_fit_info(whose='mine')
other_results = data_loader.get_fit_info(whose='others')

# %%
 fit_results
# Out:
# OrderedDict([('ma-ratio_FKFK_nnlo',
#               {'A_a': '-1.9(1.1)',
#                'A_k': '3.4(2.3)',
#                'A_loga': nan,
#                'A_p': '-1.0(1.6)',
#                'L_4': '0.0051(42)',
#                'L_5': '0.0015(13)',
#                'Q': 0.0011749638684156554,
#                'Unnamed: 0': 24L,
#                'chi2/df': 2.4229518230984435,
#                'delta_su2': '-0.00243(20)',
#                'fit': '1.1788(30)',
#                'logGBF': 53.78529931609321,
#                'name': 'ma-ratio_FKFK_nnlo',
#                'vol corr': 0L}),
#              ('ma-ratio_FKFK_nnlo_FV',
#               {'A_a': '-1.5(1.2)',
#                'A_k': '2.7(2.5)',
#                'A_loga': nan,
#                'A_p': '-0.6(1.7)',
#                'L_4': '0.0037(37)',
#                'L_5': '0.0014(11)',
#                'Q': 0.002865049435100901,
#                'Unnamed: 0': 28L,
#                'chi2/df': 2.2519290256597526,
#                'delta_su2': '-0.00245(20)',
#                'fit': '1.1795(31)',
#                'logGBF': 54.84884677405852,
#                'name': 'ma-ratio_FKFK_nnlo_FV',
#                'vol corr': 10L}),
#              ('ma-ratio_FKFK_nnlo_FV_alphaS',
#               {'A_a': '-1.5(2.9)',
#                'A_k': '2.8(2.6)',
#                'A_loga': '-0.2(4.2)',
#                'A_p': '-0.6(1.7)',
#                'L_4': '0.0037(38)',
#                'L_5': '0.0014(11)',
#                'Q': 0.0028661531724875552,
#                'Unnamed: 0': 30L,
#                'chi2/df': 2.251853756624868,
#                'delta_su2': '-0.00244(22)',
#                'fit': '1.1794(42)',
#                'logGBF': 54.676464118674424,
#                'name': 'ma-ratio_FKFK_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('ma-ratio_FKFK_nnlo_FV_alphaS_logSq',
#               {'A_a': '7.0(3.2)',
#                'A_k': '-4.1(2.1)',
#                'A_loga': '4.1(4.2)',
#                'A_p': '0.9(1.2)',
#                'L_4': '-0.00412(27)',
#                'L_5': '-0.00066(21)',
#                'Q': 0.17897591218508094,
#                'Unnamed: 0': 31L,
#                'chi2/df': 1.3117441466580468,
#                'delta_su2': '-0.00249(22)',
#                'fit': '1.1811(43)',
#                'logGBF': 51.947794632690936,
#                'name': 'ma-ratio_FKFK_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('ma-ratio_FKFK_nnlo_FV_logSq',
#               {'A_a': '8.5(2.2)',
#                'A_k': '-3.4(2.4)',
#                'A_loga': nan,
#                'A_p': '1.3(1.0)',
#                'L_4': '-0.00397(32)',
#                'L_5': '-0.00068(24)',
#                'Q': 0.14809721102328946,
#                'Unnamed: 0': 29L,
#                'chi2/df': 1.3656325190092495,
#                'delta_su2': '-0.00245(21)',
#                'fit': '1.1795(36)',
#                'logGBF': 52.63755205140688,
#                'name': 'ma-ratio_FKFK_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('ma-ratio_FKFK_nnlo_alphaS',
#               {'A_a': '-1.7(2.8)',
#                'A_k': '3.4(2.3)',
#                'A_loga': '-0.3(4.2)',
#                'A_p': '-1.1(1.7)',
#                'L_4': '0.0051(42)',
#                'L_5': '0.0015(13)',
#                'Q': 0.0011776642233710835,
#                'Unnamed: 0': 26L,
#                'chi2/df': 2.4225188765053063,
#                'delta_su2': '-0.00242(21)',
#                'fit': '1.1786(41)',
#                'logGBF': 53.6138044206829,
#                'name': 'ma-ratio_FKFK_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('ma-ratio_FKFK_nnlo_alphaS_logSq',
#               {'A_a': '-1.6(2.9)',
#                'A_k': '3.3(2.5)',
#                'A_loga': '-0.5(4.2)',
#                'A_p': '-1.6(1.7)',
#                'L_4': '0.0036(41)',
#                'L_5': '0.0004(11)',
#                'Q': 0.012785980060888371,
#                'Unnamed: 0': 27L,
#                'chi2/df': 1.948342669365068,
#                'delta_su2': '-0.00246(22)',
#                'fit': '1.1801(43)',
#                'logGBF': 57.13580394157496,
#                'name': 'ma-ratio_FKFK_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('ma-ratio_FKFK_nnlo_logSq',
#               {'A_a': '-1.8(1.3)',
#                'A_k': '3.2(2.5)',
#                'A_loga': nan,
#                'A_p': '-1.6(1.7)',
#                'L_4': '0.0035(41)',
#                'L_5': '0.0004(11)',
#                'Q': 0.012742708317500451,
#                'Unnamed: 0': 25L,
#                'chi2/df': 1.9490607620667169,
#                'delta_su2': '-0.00247(20)',
#                'fit': '1.1804(32)',
#                'logGBF': 57.29434323992377,
#                'name': 'ma-ratio_FKFK_nnlo_logSq',
#                'vol corr': 0L}),
#              ('ma-ratio_FKFpi_nnlo',
#               {'A_a': '-1.54(94)',
#                'A_k': '2.2(1.9)',
#                'A_loga': nan,
#                'A_p': '0.3(1.1)',
#                'L_4': '0.0056(43)',
#                'L_5': '0.0018(13)',
#                'Q': 0.0007015755016541415,
#                'Unnamed: 0': 32L,
#                'chi2/df': 2.5193316249474256,
#                'delta_su2': '-0.00203(18)',
#                'fit': '1.1831(30)',
#                'logGBF': 53.49927329229618,
#                'name': 'ma-ratio_FKFpi_nnlo',
#                'vol corr': 0L}),
#              ('ma-ratio_FKFpi_nnlo_FV',
#               {'A_a': '-1.1(1.2)',
#                'A_k': '1.8(2.1)',
#                'A_loga': nan,
#                'A_p': '0.5(1.2)',
#                'L_4': '0.0035(37)',
#                'L_5': '0.0013(11)',
#                'Q': 0.002223024739665253,
#                'Unnamed: 0': 36L,
#                'chi2/df': 2.3012386914254943,
#                'delta_su2': '-0.00206(18)',
#                'fit': '1.1840(33)',
#                'logGBF': 54.71695870834564,
#                'name': 'ma-ratio_FKFpi_nnlo_FV',
#                'vol corr': 10L}),
#              ('ma-ratio_FKFpi_nnlo_FV_alphaS',
#               {'A_a': '-1.2(2.9)',
#                'A_k': '1.8(2.1)',
#                'A_loga': '0.1(4.2)',
#                'A_p': '0.5(1.2)',
#                'L_4': '0.0035(37)',
#                'L_5': '0.0013(11)',
#                'Q': 0.00222342568374387,
#                'Unnamed: 0': 38L,
#                'chi2/df': 2.301203829821867,
#                'delta_su2': '-0.00206(20)',
#                'fit': '1.1840(46)',
#                'logGBF': 54.542174871650744,
#                'name': 'ma-ratio_FKFpi_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('ma-ratio_FKFpi_nnlo_FV_alphaS_logSq',
#               {'A_a': '2.9(3.3)',
#                'A_k': '2.2(3.6)',
#                'A_loga': '1.4(4.3)',
#                'A_p': '3.3(1.1)',
#                'L_4': '-0.00300(53)',
#                'L_5': '-0.00120(45)',
#                'Q': 0.2558416838081667,
#                'Unnamed: 0': 39L,
#                'chi2/df': 1.2032131241196935,
#                'delta_su2': '-0.00219(22)',
#                'fit': '1.1888(54)',
#                'logGBF': 56.68954814405907,
#                'name': 'ma-ratio_FKFpi_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('ma-ratio_FKFpi_nnlo_FV_logSq',
#               {'A_a': '3.6(2.4)',
#                'A_k': '2.5(3.5)',
#                'A_loga': nan,
#                'A_p': '3.3(1.1)',
#                'L_4': '-0.00296(52)',
#                'L_5': '-0.00123(45)',
#                'Q': 0.25038352677556386,
#                'Unnamed: 0': 37L,
#                'chi2/df': 1.2100681639399091,
#                'delta_su2': '-0.00216(20)',
#                'fit': '1.1878(40)',
#                'logGBF': 56.95551011592264,
#                'name': 'ma-ratio_FKFpi_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('ma-ratio_FKFpi_nnlo_alphaS',
#               {'A_a': '-1.5(2.8)',
#                'A_k': '2.2(1.9)',
#                'A_loga': '-0.08(4.18)',
#                'A_p': '0.3(1.1)',
#                'L_4': '0.0056(43)',
#                'L_5': '0.0018(13)',
#                'Q': 0.0007016535762082553,
#                'Unnamed: 0': 34L,
#                'chi2/df': 2.519311006593555,
#                'delta_su2': '-0.00203(20)',
#                'fit': '1.1831(44)',
#                'logGBF': 53.32247577457794,
#                'name': 'ma-ratio_FKFpi_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('ma-ratio_FKFpi_nnlo_alphaS_logSq',
#               {'A_a': '-1.2(2.9)',
#                'A_k': '1.5(2.0)',
#                'A_loga': '-0.1(4.2)',
#                'A_p': '0.2(1.1)',
#                'L_4': '0.0035(40)',
#                'L_5': '0.0005(10)',
#                'Q': 0.0055348351648924115,
#                'Unnamed: 0': 35L,
#                'chi2/df': 2.1212572428631282,
#                'delta_su2': '-0.00213(21)',
#                'fit': '1.1866(48)',
#                'logGBF': 56.146299422420604,
#                'name': 'ma-ratio_FKFpi_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('ma-ratio_FKFpi_nnlo_logSq',
#               {'A_a': '-1.3(1.2)',
#                'A_k': '1.5(2.0)',
#                'A_loga': nan,
#                'A_p': '0.2(1.1)',
#                'L_4': '0.0034(40)',
#                'L_5': '0.0005(10)',
#                'Q': 0.005533881532138693,
#                'Unnamed: 0': 33L,
#                'chi2/df': 2.1212919945925304,
#                'delta_su2': '-0.00213(19)',
#                'fit': '1.1867(35)',
#                'logGBF': 56.31545014734784,
#                'name': 'ma-ratio_FKFpi_nnlo_logSq',
#                'vol corr': 0L}),
#              ('ma-ratio_FpiFpi_nnlo',
#               {'A_a': '-0.96(92)',
#                'A_k': '0.6(1.5)',
#                'A_loga': nan,
#                'A_p': '1.31(66)',
#                'L_4': '0.0053(43)',
#                'L_5': '0.0023(13)',
#                'Q': 0.0003941016910336783,
#                'Unnamed: 0': 40L,
#                'chi2/df': 2.625229072537876,
#                'delta_su2': '-0.00148(17)',
#                'fit': '1.1856(33)',
#                'logGBF': 52.30021734812309,
#                'name': 'ma-ratio_FpiFpi_nnlo',
#                'vol corr': 0L}),
#              ('ma-ratio_FpiFpi_nnlo_FV',
#               {'A_a': '-0.5(1.2)',
#                'A_k': '0.3(1.8)',
#                'A_loga': nan,
#                'A_p': '1.43(76)',
#                'L_4': '0.0029(36)',
#                'L_5': '0.0016(10)',
#                'Q': 0.0015681138165584126,
#                'Unnamed: 0': 44L,
#                'chi2/df': 2.368227251832141,
#                'delta_su2': '-0.00152(18)',
#                'fit': '1.1869(38)',
#                'logGBF': 53.66959153389541,
#                'name': 'ma-ratio_FpiFpi_nnlo_FV',
#                'vol corr': 10L}),
#              ('ma-ratio_FpiFpi_nnlo_FV_alphaS',
#               {'A_a': '-0.9(2.9)',
#                'A_k': '0.3(1.8)',
#                'A_loga': '0.6(4.2)',
#                'A_p': '1.45(78)',
#                'L_4': '0.0029(36)',
#                'L_5': '0.0016(10)',
#                'Q': 0.0015796550630911724,
#                'Unnamed: 0': 46L,
#                'chi2/df': 2.3668291723277224,
#                'delta_su2': '-0.00153(21)',
#                'fit': '1.1874(54)',
#                'logGBF': 53.48155590259186,
#                'name': 'ma-ratio_FpiFpi_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('ma-ratio_FpiFpi_nnlo_FV_alphaS_logSq',
#               {'A_a': '2.3(3.1)',
#                'A_k': '3.7(2.9)',
#                'A_loga': '1.1(4.3)',
#                'A_p': '5.1(1.1)',
#                'L_4': '-0.00282(43)',
#                'L_5': '-0.00153(47)',
#                'Q': 0.53475590125398,
#                'Unnamed: 0': 47L,
#                'chi2/df': 0.9288854393330976,
#                'delta_su2': '-0.00171(26)',
#                'fit': '1.1936(72)',
#                'logGBF': 58.09295083451996,
#                'name': 'ma-ratio_FpiFpi_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('ma-ratio_FpiFpi_nnlo_FV_logSq',
#               {'A_a': '3.0(2.2)',
#                'A_k': '3.8(2.9)',
#                'A_loga': nan,
#                'A_p': '5.1(1.1)',
#                'L_4': '-0.00280(42)',
#                'L_5': '-0.00154(46)',
#                'Q': 0.5295457416825634,
#                'Unnamed: 0': 45L,
#                'chi2/df': 0.9333170659745542,
#                'delta_su2': '-0.00168(22)',
#                'fit': '1.1926(55)',
#                'logGBF': 58.299002260040176,
#                'name': 'ma-ratio_FpiFpi_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('ma-ratio_FpiFpi_nnlo_alphaS',
#               {'A_a': '-1.3(2.8)',
#                'A_k': '0.5(1.5)',
#                'A_loga': '0.5(4.2)',
#                'A_p': '1.32(67)',
#                'L_4': '0.0053(43)',
#                'L_5': '0.0023(13)',
#                'Q': 0.0003960637451286424,
#                'Unnamed: 0': 42L,
#                'chi2/df': 2.6243250405478533,
#                'delta_su2': '-0.00149(20)',
#                'fit': '1.1860(49)',
#                'logGBF': 52.11272787303022,
#                'name': 'ma-ratio_FpiFpi_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('ma-ratio_FpiFpi_nnlo_alphaS_logSq',
#               {'A_a': '-0.5(2.9)',
#                'A_k': '-0.9(1.9)',
#                'A_loga': '0.8(4.2)',
#                'A_p': '1.74(74)',
#                'L_4': '0.0017(31)',
#                'L_5': '0.00085(87)',
#                'Q': 0.0016015787769341904,
#                'Unnamed: 0': 43L,
#                'chi2/df': 2.3642002241213467,
#                'delta_su2': '-0.00168(23)',
#                'fit': '1.1925(59)',
#                'logGBF': 52.833637005393506,
#                'name': 'ma-ratio_FpiFpi_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('ma-ratio_FpiFpi_nnlo_logSq',
#               {'A_a': '3.5(2.4)',
#                'A_k': '4.0(2.9)',
#                'A_loga': nan,
#                'A_p': '6.0(1.1)',
#                'L_4': '-0.00296(41)',
#                'L_5': '-0.00159(43)',
#                'Q': 0.1157172850083545,
#                'Unnamed: 0': 41L,
#                'chi2/df': 1.4328975449861012,
#                'delta_su2': '-0.00166(22)',
#                'fit': '1.1918(56)',
#                'logGBF': 53.46695192659029,
#                'name': 'ma-ratio_FpiFpi_nnlo_logSq',
#                'vol corr': 0L}),
#              ('ma_FKFK_nnlo',
#               {'A_a': '0.74(54)',
#                'A_k': '0.2(3.1)',
#                'A_loga': nan,
#                'A_p': '0.2(1.0)',
#                'L_4': nan,
#                'L_5': '0.00031(62)',
#                'Q': 0.005661124388521418,
#                'Unnamed: 0': 0L,
#                'chi2/df': 2.116704495152887,
#                'delta_su2': '-0.00234(18)',
#                'fit': '1.1756(18)',
#                'logGBF': 54.69611723943947,
#                'name': 'ma_FKFK_nnlo',
#                'vol corr': 0L}),
#              ('ma_FKFK_nnlo_FV',
#               {'A_a': '0.60(54)',
#                'A_k': '0.07(3.15)',
#                'A_loga': nan,
#                'A_p': '0.3(1.0)',
#                'L_4': nan,
#                'L_5': '0.00034(62)',
#                'Q': 0.0179674366292765,
#                'Unnamed: 0': 4L,
#                'chi2/df': 1.8754193181840157,
#                'delta_su2': '-0.00233(18)',
#                'fit': '1.1754(18)',
#                'logGBF': 56.61995135713065,
#                'name': 'ma_FKFK_nnlo_FV',
#                'vol corr': 10L}),
#              ('ma_FKFK_nnlo_FV_alphaS',
#               {'A_a': '0.04(2.78)',
#                'A_k': '-0.001(3.159)',
#                'A_loga': '0.9(4.2)',
#                'A_p': '0.3(1.0)',
#                'L_4': nan,
#                'L_5': '0.00036(63)',
#                'Q': 0.018185661747814358,
#                'Unnamed: 0': 6L,
#                'chi2/df': 1.8727988962965063,
#                'delta_su2': '-0.00234(19)',
#                'fit': '1.1758(30)',
#                'logGBF': 56.46090112180818,
#                'name': 'ma_FKFK_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('ma_FKFK_nnlo_FV_alphaS_logSq',
#               {'A_a': '-0.02(2.78)',
#                'A_k': '-0.1(3.2)',
#                'A_loga': '0.8(4.2)',
#                'A_p': '0.4(1.0)',
#                'L_4': nan,
#                'L_5': '-0.00006(63)',
#                'Q': 0.17567728614800948,
#                'Unnamed: 0': 7L,
#                'chi2/df': 1.3171353878890646,
#                'delta_su2': '-0.00241(20)',
#                'fit': '1.1781(30)',
#                'logGBF': 60.88532153148427,
#                'name': 'ma_FKFK_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('ma_FKFK_nnlo_FV_logSq',
#               {'A_a': '0.52(54)',
#                'A_k': '-0.05(3.16)',
#                'A_loga': nan,
#                'A_p': '0.4(1.0)',
#                'L_4': nan,
#                'L_5': '-0.00008(62)',
#                'Q': 0.17415792011944842,
#                'Unnamed: 0': 5L,
#                'chi2/df': 1.3196450871229837,
#                'delta_su2': '-0.00239(18)',
#                'fit': '1.1776(19)',
#                'logGBF': 61.04525588168972,
#                'name': 'ma_FKFK_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('ma_FKFK_nnlo_alphaS',
#               {'A_a': '0.1(2.8)',
#                'A_k': '0.2(3.2)',
#                'A_loga': '0.9(4.2)',
#                'A_p': '0.3(1.0)',
#                'L_4': nan,
#                'L_5': '0.00033(63)',
#                'Q': 0.005752761146258101,
#                'Unnamed: 0': 2L,
#                'chi2/df': 2.113460838412341,
#                'delta_su2': '-0.00235(19)',
#                'fit': '1.1761(30)',
#                'logGBF': 54.542349301004144,
#                'name': 'ma_FKFK_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('ma_FKFK_nnlo_alphaS_logSq',
#               {'A_a': '0.06(2.78)',
#                'A_k': '0.07(3.16)',
#                'A_loga': '0.9(4.2)',
#                'A_p': '0.4(1.0)',
#                'L_4': nan,
#                'L_5': '-0.00009(63)',
#                'Q': 0.04563347278803392,
#                'Unnamed: 0': 3L,
#                'chi2/df': 1.6651476793806907,
#                'delta_su2': '-0.00242(20)',
#                'fit': '1.1784(30)',
#                'logGBF': 58.107136879247314,
#                'name': 'ma_FKFK_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('ma_FKFK_nnlo_logSq',
#               {'A_a': '0.66(54)',
#                'A_k': '0.1(3.2)',
#                'A_loga': nan,
#                'A_p': '0.3(1.0)',
#                'L_4': nan,
#                'L_5': '-0.00011(62)',
#                'Q': 0.04503473839877492,
#                'Unnamed: 0': 1L,
#                'chi2/df': 1.6682569133523668,
#                'delta_su2': '-0.00240(18)',
#                'fit': '1.1779(19)',
#                'logGBF': 58.26195672924803,
#                'name': 'ma_FKFK_nnlo_logSq',
#                'vol corr': 0L}),
#              ('ma_FKFpi_nnlo',
#               {'A_a': '1.14(40)',
#                'A_k': '-0.5(2.4)',
#                'A_loga': nan,
#                'A_p': '1.14(44)',
#                'L_4': nan,
#                'L_5': '0.00032(56)',
#                'Q': 0.00754571057117789,
#                'Unnamed: 0': 8L,
#                'chi2/df': 2.0582310475682646,
#                'delta_su2': '-0.00193(16)',
#                'fit': '1.1796(23)',
#                'logGBF': 54.82244800236693,
#                'name': 'ma_FKFpi_nnlo',
#                'vol corr': 0L}),
#              ('ma_FKFpi_nnlo_FV',
#               {'A_a': '0.93(40)',
#                'A_k': '-0.2(2.4)',
#                'A_loga': nan,
#                'A_p': '1.07(44)',
#                'L_4': nan,
#                'L_5': '0.00025(56)',
#                'Q': 0.03401874611519965,
#                'Unnamed: 0': 12L,
#                'chi2/df': 1.7333238630647805,
#                'delta_su2': '-0.00193(16)',
#                'fit': '1.1795(24)',
#                'logGBF': 57.43337655027622,
#                'name': 'ma_FKFpi_nnlo_FV',
#                'vol corr': 10L}),
#              ('ma_FKFpi_nnlo_FV_alphaS',
#               {'A_a': '0.2(2.8)',
#                'A_k': '-0.3(2.4)',
#                'A_loga': '1.1(4.2)',
#                'A_p': '1.08(44)',
#                'L_4': nan,
#                'L_5': '0.00027(57)',
#                'Q': 0.034669633700122084,
#                'Unnamed: 0': 14L,
#                'chi2/df': 1.728983692292111,
#                'delta_su2': '-0.00195(18)',
#                'fit': '1.1802(36)',
#                'logGBF': 57.278143899636994,
#                'name': 'ma_FKFpi_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('ma_FKFpi_nnlo_FV_alphaS_logSq',
#               {'A_a': '0.1(2.8)',
#                'A_k': '-0.4(2.4)',
#                'A_loga': '1.1(4.2)',
#                'A_p': '1.37(44)',
#                'L_4': nan,
#                'L_5': '-0.00016(57)',
#                'Q': 0.2712610348762173,
#                'Unnamed: 0': 15L,
#                'chi2/df': 1.1843792172624457,
#                'delta_su2': '-0.00205(19)',
#                'fit': '1.1837(37)',
#                'logGBF': 61.66415071987628,
#                'name': 'ma_FKFpi_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('ma_FKFpi_nnlo_FV_logSq',
#               {'A_a': '0.86(40)',
#                'A_k': '-0.3(2.4)',
#                'A_loga': nan,
#                'A_p': '1.37(44)',
#                'L_4': nan,
#                'L_5': '-0.00018(56)',
#                'Q': 0.2676394353215831,
#                'Unnamed: 0': 13L,
#                'chi2/df': 1.1887354652240998,
#                'delta_su2': '-0.00203(17)',
#                'fit': '1.1830(25)',
#                'logGBF': 61.81905454061077,
#                'name': 'ma_FKFpi_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('ma_FKFpi_nnlo_alphaS',
#               {'A_a': '0.3(2.8)',
#                'A_k': '-0.5(2.4)',
#                'A_loga': '1.3(4.2)',
#                'A_p': '1.14(44)',
#                'L_4': nan,
#                'L_5': '0.00034(57)',
#                'Q': 0.007758587480036015,
#                'Unnamed: 0': 10L,
#                'chi2/df': 2.052520263978685,
#                'delta_su2': '-0.00195(18)',
#                'fit': '1.1804(36)',
#                'logGBF': 54.67718195007475,
#                'name': 'ma_FKFpi_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('ma_FKFpi_nnlo_alphaS_logSq',
#               {'A_a': '0.2(2.8)',
#                'A_k': '-0.9(2.4)',
#                'A_loga': '1.3(4.2)',
#                'A_p': '1.47(44)',
#                'L_4': nan,
#                'L_5': '-0.00005(57)',
#                'Q': 0.04386292685090985,
#                'Unnamed: 0': 11L,
#                'chi2/df': 1.674450742517831,
#                'delta_su2': '-0.00205(19)',
#                'fit': '1.1839(36)',
#                'logGBF': 57.714600451784975,
#                'name': 'ma_FKFpi_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('ma_FKFpi_nnlo_logSq',
#               {'A_a': '1.09(40)',
#                'A_k': '-0.8(2.4)',
#                'A_loga': nan,
#                'A_p': '1.46(44)',
#                'L_4': nan,
#                'L_5': '-0.00007(56)',
#                'Q': 0.04275666164960075,
#                'Unnamed: 0': 9L,
#                'chi2/df': 1.6804357113899044,
#                'delta_su2': '-0.00203(17)',
#                'fit': '1.1830(24)',
#                'logGBF': 57.85766761755261,
#                'name': 'ma_FKFpi_nnlo_logSq',
#                'vol corr': 0L}),
#              ('ma_FpiFpi_nnlo',
#               {'A_a': '1.41(29)',
#                'A_k': '-0.9(1.7)',
#                'A_loga': nan,
#                'A_p': '1.50(16)',
#                'L_4': nan,
#                'L_5': '0.00036(48)',
#                'Q': 0.008492980151789342,
#                'Unnamed: 0': 16L,
#                'chi2/df': 2.0338925895558546,
#                'delta_su2': '-0.00137(16)',
#                'fit': '1.1816(30)',
#                'logGBF': 54.28134512731921,
#                'name': 'ma_FpiFpi_nnlo',
#                'vol corr': 0L}),
#              ('ma_FpiFpi_nnlo_FV',
#               {'A_a': '1.19(28)',
#                'A_k': '-0.5(1.7)',
#                'A_loga': nan,
#                'A_p': '1.47(16)',
#                'L_4': nan,
#                'L_5': '0.00023(48)',
#                'Q': 0.05010566135366663,
#                'Unnamed: 0': 20L,
#                'chi2/df': 1.6430119315532834,
#                'delta_su2': '-0.00138(17)',
#                'fit': '1.1819(31)',
#                'logGBF': 57.53310645912035,
#                'name': 'ma_FpiFpi_nnlo_FV',
#                'vol corr': 10L}),
#              ('ma_FpiFpi_nnlo_FV_alphaS',
#               {'A_a': '0.3(2.8)',
#                'A_k': '-0.5(1.7)',
#                'A_loga': '1.3(4.2)',
#                'A_p': '1.47(16)',
#                'L_4': nan,
#                'L_5': '0.00025(48)',
#                'Q': 0.05145650301055698,
#                'Unnamed: 0': 22L,
#                'chi2/df': 1.6366719589740937,
#                'delta_su2': '-0.00140(19)',
#                'fit': '1.1829(45)',
#                'logGBF': 57.38388185777456,
#                'name': 'ma_FpiFpi_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('ma_FpiFpi_nnlo_FV_alphaS_logSq',
#               {'A_a': '0.2(2.8)',
#                'A_k': '-0.9(1.7)',
#                'A_loga': '1.4(4.2)',
#                'A_p': '1.92(16)',
#                'L_4': nan,
#                'L_5': '-0.00013(48)',
#                'Q': 0.29291998325842783,
#                'Unnamed: 0': 23L,
#                'chi2/df': 1.159110300420074,
#                'delta_su2': '-0.00155(20)',
#                'fit': '1.1879(46)',
#                'logGBF': 61.205468582772454,
#                'name': 'ma_FpiFpi_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('ma_FpiFpi_nnlo_FV_logSq',
#               {'A_a': '1.14(29)',
#                'A_k': '-0.9(1.7)',
#                'A_loga': nan,
#                'A_p': '1.92(16)',
#                'L_4': nan,
#                'L_5': '-0.00015(48)',
#                'Q': 0.28680528701668506,
#                'Unnamed: 0': 21L,
#                'chi2/df': 1.166114705944144,
#                'delta_su2': '-0.00152(17)',
#                'fit': '1.1868(33)',
#                'logGBF': 61.349740703846436,
#                'name': 'ma_FpiFpi_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('ma_FpiFpi_nnlo_alphaS',
#               {'A_a': '0.4(2.8)',
#                'A_k': '-1.0(1.7)',
#                'A_loga': '1.5(4.2)',
#                'A_p': '1.50(16)',
#                'L_4': nan,
#                'L_5': '0.00039(49)',
#                'Q': 0.008848487543489849,
#                'Unnamed: 0': 18L,
#                'chi2/df': 2.0254140817198,
#                'delta_su2': '-0.00140(19)',
#                'fit': '1.1828(44)',
#                'logGBF': 54.14745841901803,
#                'name': 'ma_FpiFpi_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('ma_FpiFpi_nnlo_alphaS_logSq',
#               {'A_a': '0.3(2.8)',
#                'A_k': '-1.7(1.8)',
#                'A_loga': '1.7(4.2)',
#                'A_p': '1.95(16)',
#                'L_4': nan,
#                'L_5': '0.00010(49)',
#                'Q': 0.02823320693574505,
#                'Unnamed: 0': 19L,
#                'chi2/df': 1.7756138287373626,
#                'delta_su2': '-0.00153(20)',
#                'fit': '1.1874(45)',
#                'logGBF': 56.0331529332674,
#                'name': 'ma_FpiFpi_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('ma_FpiFpi_nnlo_logSq',
#               {'A_a': '1.40(29)',
#                'A_k': '-1.7(1.8)',
#                'A_loga': nan,
#                'A_p': '1.95(16)',
#                'L_4': nan,
#                'L_5': '0.00008(49)',
#                'Q': 0.02701172447538053,
#                'Unnamed: 0': 17L,
#                'chi2/df': 1.7855452071748343,
#                'delta_su2': '-0.00149(17)',
#                'fit': '1.1861(31)',
#                'logGBF': 56.15615564002169,
#                'name': 'ma_FpiFpi_nnlo_logSq',
#                'vol corr': 0L}),
#              ('xpt-ratio_FKFK_nnlo',
#               {'A_a': '-4.48(48)',
#                'A_k': '6.1(2.4)',
#                'A_loga': nan,
#                'A_p': '-1.7(1.4)',
#                'L_4': '0.0022(36)',
#                'L_5': '-0.0002(12)',
#                'Q': 0.016821021088336215,
#                'Unnamed: 0': 72L,
#                'chi2/df': 1.8896893001411528,
#                'delta_su2': '-0.00230(18)',
#                'fit': '1.1744(20)',
#                'logGBF': 57.89082685965462,
#                'name': 'xpt-ratio_FKFK_nnlo',
#                'vol corr': 0L}),
#              ('xpt-ratio_FKFK_nnlo_FV',
#               {'A_a': '-5.10(45)',
#                'A_k': '2.1(1.6)',
#                'A_loga': nan,
#                'A_p': '3.11(59)',
#                'L_4': '-0.00354(42)',
#                'L_5': '-0.00090(17)',
#                'Q': 0.8703494290556363,
#                'Unnamed: 0': 76L,
#                'chi2/df': 0.6205142608398684,
#                'delta_su2': '-0.00240(19)',
#                'fit': '1.1778(29)',
#                'logGBF': 64.51697269817535,
#                'name': 'xpt-ratio_FKFK_nnlo_FV',
#                'vol corr': 10L}),
#              ('xpt-ratio_FKFK_nnlo_FV_alphaS',
#               {'A_a': '-4.0(2.8)',
#                'A_k': '2.0(1.6)',
#                'A_loga': '-1.7(4.1)',
#                'A_p': '3.15(59)',
#                'L_4': '-0.00356(41)',
#                'L_5': '-0.00090(16)',
#                'Q': 0.8787637967271876,
#                'Unnamed: 0': 78L,
#                'chi2/df': 0.6101178069658175,
#                'delta_su2': '-0.00237(20)',
#                'fit': '1.1769(36)',
#                'logGBF': 64.3787393740013,
#                'name': 'xpt-ratio_FKFK_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('xpt-ratio_FKFK_nnlo_FV_alphaS_logSq',
#               {'A_a': '-3.7(2.8)',
#                'A_k': '3.2(2.6)',
#                'A_loga': '-1.2(4.1)',
#                'A_p': '3.7(1.2)',
#                'L_4': '-0.00316(46)',
#                'L_5': '-0.00124(27)',
#                'Q': 0.8276167400970849,
#                'Unnamed: 0': 79L,
#                'chi2/df': 0.6687462967090356,
#                'delta_su2': '-0.00235(20)',
#                'fit': '1.1759(35)',
#                'logGBF': 64.38979596123374,
#                'name': 'xpt-ratio_FKFK_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('xpt-ratio_FKFK_nnlo_FV_logSq',
#               {'A_a': '-4.50(24)',
#                'A_k': '3.2(2.6)',
#                'A_loga': nan,
#                'A_p': '3.7(1.2)',
#                'L_4': '-0.00317(46)',
#                'L_5': '-0.00124(27)',
#                'Q': 0.8224361308910333,
#                'Unnamed: 0': 77L,
#                'chi2/df': 0.6741892974377827,
#                'delta_su2': '-0.00237(19)',
#                'fit': '1.1766(25)',
#                'logGBF': 64.5299763936433,
#                'name': 'xpt-ratio_FKFK_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('xpt-ratio_FKFK_nnlo_alphaS',
#               {'A_a': '-3.5(2.8)',
#                'A_k': '6.2(2.4)',
#                'A_loga': '-1.6(4.2)',
#                'A_p': '-1.7(1.4)',
#                'L_4': '0.0022(36)',
#                'L_5': '-0.0003(12)',
#                'Q': 0.01752862420045217,
#                'Unnamed: 0': 74L,
#                'chi2/df': 1.8807789659971776,
#                'delta_su2': '-0.00228(19)',
#                'fit': '1.1735(32)',
#                'logGBF': 57.768989084238044,
#                'name': 'xpt-ratio_FKFK_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('xpt-ratio_FKFK_nnlo_alphaS_logSq',
#               {'A_a': '-3.5(2.8)',
#                'A_k': '6.2(2.3)',
#                'A_loga': '-1.8(4.2)',
#                'A_p': '-2.8(1.4)',
#                'L_4': '0.0048(42)',
#                'L_5': '-0.0007(11)',
#                'Q': 0.02083403679252962,
#                'Unnamed: 0': 75L,
#                'chi2/df': 1.8431233456884568,
#                'delta_su2': '-0.00229(19)',
#                'fit': '1.1741(32)',
#                'logGBF': 58.319211983692405,
#                'name': 'xpt-ratio_FKFK_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('xpt-ratio_FKFK_nnlo_logSq',
#               {'A_a': '-4.64(49)',
#                'A_k': '6.1(2.3)',
#                'A_loga': nan,
#                'A_p': '-2.8(1.4)',
#                'L_4': '0.0048(42)',
#                'L_5': '-0.0006(12)',
#                'Q': 0.019771573047076274,
#                'Unnamed: 0': 73L,
#                'chi2/df': 1.8545849683191835,
#                'delta_su2': '-0.00232(18)',
#                'fit': '1.1752(21)',
#                'logGBF': 58.42017905785558,
#                'name': 'xpt-ratio_FKFK_nnlo_logSq',
#                'vol corr': 0L}),
#              ('xpt-ratio_FKFpi_nnlo',
#               {'A_a': '-3.70(34)',
#                'A_k': '4.1(1.6)',
#                'A_loga': nan,
#                'A_p': '-0.04(88)',
#                'L_4': '0.0044(36)',
#                'L_5': '0.0003(12)',
#                'Q': 0.008144047237648177,
#                'Unnamed: 0': 80L,
#                'chi2/df': 2.0425456360865057,
#                'delta_su2': '-0.00195(17)',
#                'fit': '1.1802(30)',
#                'logGBF': 57.70358280736284,
#                'name': 'xpt-ratio_FKFpi_nnlo',
#                'vol corr': 0L}),
#              ('xpt-ratio_FKFpi_nnlo_FV',
#               {'A_a': '-4.08(20)',
#                'A_k': '4.5(1.9)',
#                'A_loga': nan,
#                'A_p': '4.1(1.0)',
#                'L_4': '-0.00284(38)',
#                'L_5': '-0.00125(25)',
#                'Q': 0.8025990220559169,
#                'Unnamed: 0': 84L,
#                'chi2/df': 0.6944210652188035,
#                'delta_su2': '-0.00201(18)',
#                'fit': '1.1823(31)',
#                'logGBF': 64.85656100792086,
#                'name': 'xpt-ratio_FKFpi_nnlo_FV',
#                'vol corr': 10L}),
#              ('xpt-ratio_FKFpi_nnlo_FV_alphaS',
#               {'A_a': '-3.4(2.8)',
#                'A_k': '4.5(1.9)',
#                'A_loga': '-1.0(4.1)',
#                'A_p': '4.1(1.0)',
#                'L_4': '-0.00284(38)',
#                'L_5': '-0.00125(25)',
#                'Q': 0.8061705102667959,
#                'Unnamed: 0': 86L,
#                'chi2/df': 0.6908442724508217,
#                'delta_su2': '-0.00199(19)',
#                'fit': '1.1816(43)',
#                'logGBF': 64.69313896905726,
#                'name': 'xpt-ratio_FKFpi_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('xpt-ratio_FKFpi_nnlo_FV_alphaS_logSq',
#               {'A_a': '-3.2(2.8)',
#                'A_k': '6.6(2.0)',
#                'A_loga': '-1.0(4.1)',
#                'A_p': '4.7(1.0)',
#                'L_4': '-0.00254(33)',
#                'L_5': '-0.00190(33)',
#                'Q': 0.7446080045622121,
#                'Unnamed: 0': 87L,
#                'chi2/df': 0.7494293857601751,
#                'delta_su2': '-0.00198(19)',
#                'fit': '1.1812(43)',
#                'logGBF': 64.00142090836124,
#                'name': 'xpt-ratio_FKFpi_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('xpt-ratio_FKFpi_nnlo_FV_logSq',
#               {'A_a': '-3.87(27)',
#                'A_k': '6.6(2.0)',
#                'A_loga': nan,
#                'A_p': '4.8(1.0)',
#                'L_4': '-0.00255(32)',
#                'L_5': '-0.00189(32)',
#                'Q': 0.7403778106242376,
#                'Unnamed: 0': 85L,
#                'chi2/df': 0.753263253240318,
#                'delta_su2': '-0.00200(18)',
#                'fit': '1.1819(32)',
#                'logGBF': 64.15218500120457,
#                'name': 'xpt-ratio_FKFpi_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('xpt-ratio_FKFpi_nnlo_alphaS',
#               {'A_a': '-3.0(2.8)',
#                'A_k': '4.1(1.6)',
#                'A_loga': '-1.1(4.2)',
#                'A_p': '-0.06(88)',
#                'L_4': '0.0044(36)',
#                'L_5': '0.0003(12)',
#                'Q': 0.008325641755670047,
#                'Unnamed: 0': 82L,
#                'chi2/df': 2.0379997136796053,
#                'delta_su2': '-0.00193(19)',
#                'fit': '1.1794(41)',
#                'logGBF': 57.5579045397222,
#                'name': 'xpt-ratio_FKFpi_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('xpt-ratio_FKFpi_nnlo_alphaS_logSq',
#               {'A_a': '-2.9(2.8)',
#                'A_k': '3.5(1.5)',
#                'A_loga': '-1.3(4.2)',
#                'A_p': '-0.52(85)',
#                'L_4': '0.0078(43)',
#                'L_5': '0.0001(12)',
#                'Q': 0.002372024796777373,
#                'Unnamed: 0': 83L,
#                'chi2/df': 2.2886809246667044,
#                'delta_su2': '-0.00198(19)',
#                'fit': '1.1815(42)',
#                'logGBF': 55.991755465791634,
#                'name': 'xpt-ratio_FKFpi_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('xpt-ratio_FKFpi_nnlo_logSq',
#               {'A_a': '-3.75(34)',
#                'A_k': '3.5(1.5)',
#                'A_loga': nan,
#                'A_p': '-0.49(85)',
#                'L_4': '0.0078(43)',
#                'L_5': '0.0002(12)',
#                'Q': 0.0022962767721299536,
#                'Unnamed: 0': 81L,
#                'chi2/df': 2.2949674270341687,
#                'delta_su2': '-0.00201(18)',
#                'fit': '1.1824(31)',
#                'logGBF': 56.12193820151264,
#                'name': 'xpt-ratio_FKFpi_nnlo_logSq',
#                'vol corr': 0L}),
#              ('xpt-ratio_FpiFpi_nnlo',
#               {'A_a': '-2.93(22)',
#                'A_k': '2.0(1.0)',
#                'A_loga': nan,
#                'A_p': '1.31(52)',
#                'L_4': '0.0053(34)',
#                'L_5': '0.0012(11)',
#                'Q': 0.003482788130263038,
#                'Unnamed: 0': 88L,
#                'chi2/df': 2.2136069194016432,
#                'delta_su2': '-0.00143(18)',
#                'fit': '1.1838(41)',
#                'logGBF': 56.552160242726146,
#                'name': 'xpt-ratio_FpiFpi_nnlo',
#                'vol corr': 0L}),
#              ('xpt-ratio_FpiFpi_nnlo_FV',
#               {'A_a': '-3.45(18)',
#                'A_k': '5.5(1.4)',
#                'A_loga': nan,
#                'A_p': '4.85(79)',
#                'L_4': '-0.00248(28)',
#                'L_5': '-0.00155(24)',
#                'Q': 0.6226200309533989,
#                'Unnamed: 0': 92L,
#                'chi2/df': 0.854932390325356,
#                'delta_su2': '-0.00153(20)',
#                'fit': '1.1873(48)',
#                'logGBF': 63.795795896857655,
#                'name': 'xpt-ratio_FpiFpi_nnlo_FV',
#                'vol corr': 10L}),
#              ('xpt-ratio_FpiFpi_nnlo_FV_alphaS',
#               {'A_a': '-3.1(2.7)',
#                'A_k': '5.5(1.4)',
#                'A_loga': '-0.6(4.1)',
#                'A_p': '4.84(80)',
#                'L_4': '-0.00248(28)',
#                'L_5': '-0.00155(24)',
#                'Q': 0.6241264625038949,
#                'Unnamed: 0': 94L,
#                'chi2/df': 0.8536661103289597,
#                'delta_su2': '-0.00152(22)',
#                'fit': '1.1868(59)',
#                'logGBF': 63.617229423282566,
#                'name': 'xpt-ratio_FpiFpi_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('xpt-ratio_FpiFpi_nnlo_FV_alphaS_logSq',
#               {'A_a': '-2.8(2.8)',
#                'A_k': '0.7(1.1)',
#                'A_loga': '-0.4(4.1)',
#                'A_p': '1.76(61)',
#                'L_4': '0.0034(32)',
#                'L_5': '0.00044(94)',
#                'Q': 0.007252513049911416,
#                'Unnamed: 0': 95L,
#                'chi2/df': 2.066350568280397,
#                'delta_su2': '-0.00153(21)',
#                'fit': '1.1875(52)',
#                'logGBF': 57.02803426521556,
#                'name': 'xpt-ratio_FpiFpi_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('xpt-ratio_FpiFpi_nnlo_FV_logSq',
#               {'A_a': '-3.06(24)',
#                'A_k': '0.7(1.1)',
#                'A_loga': nan,
#                'A_p': '1.76(61)',
#                'L_4': '0.0034(32)',
#                'L_5': '0.00045(94)',
#                'Q': 0.007227468747921897,
#                'Unnamed: 0': 93L,
#                'chi2/df': 2.067058412288072,
#                'delta_su2': '-0.00154(19)',
#                'fit': '1.1878(40)',
#                'logGBF': 57.20716560206319,
#                'name': 'xpt-ratio_FpiFpi_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('xpt-ratio_FpiFpi_nnlo_alphaS',
#               {'A_a': '-2.7(2.8)',
#                'A_k': '2.0(1.0)',
#                'A_loga': '-0.4(4.1)',
#                'A_p': '1.31(53)',
#                'L_4': '0.0053(34)',
#                'L_5': '0.0012(11)',
#                'Q': 0.003492855454725639,
#                'Unnamed: 0': 90L,
#                'chi2/df': 2.2130378288073813,
#                'delta_su2': '-0.00142(21)',
#                'fit': '1.1835(53)',
#                'logGBF': 56.373052223364255,
#                'name': 'xpt-ratio_FpiFpi_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('xpt-ratio_FpiFpi_nnlo_alphaS_logSq',
#               {'A_a': '-2.6(2.8)',
#                'A_k': '0.43(99)',
#                'A_loga': '-0.4(4.1)',
#                'A_p': '1.45(51)',
#                'L_4': '0.0093(44)',
#                'L_5': '0.0021(13)',
#                'Q': 0.00010209164783091724,
#                'Unnamed: 0': 91L,
#                'chi2/df': 2.8666689852634866,
#                'delta_su2': '-0.00148(20)',
#                'fit': '1.1857(49)',
#                'logGBF': 51.153946960649726,
#                'name': 'xpt-ratio_FpiFpi_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('xpt-ratio_FpiFpi_nnlo_logSq',
#               {'A_a': '-2.81(23)',
#                'A_k': '0.43(99)',
#                'A_loga': nan,
#                'A_p': '1.45(50)',
#                'L_4': '0.0093(44)',
#                'L_5': '0.0021(13)',
#                'Q': 0.0001018198935519676,
#                'Unnamed: 0': 89L,
#                'chi2/df': 2.8671374076228853,
#                'delta_su2': '-0.00149(18)',
#                'fit': '1.1860(36)',
#                'logGBF': 51.3342877333341,
#                'name': 'xpt-ratio_FpiFpi_nnlo_logSq',
#                'vol corr': 0L}),
#              ('xpt_FKFK_nnlo',
#               {'A_a': '-4.14(52)',
#                'A_k': '4.8(3.0)',
#                'A_loga': nan,
#                'A_p': '-0.09(96)',
#                'L_4': nan,
#                'L_5': '-0.00064(58)',
#                'Q': 0.019247705577301686,
#                'Unnamed: 0': 48L,
#                'chi2/df': 1.860447241308735,
#                'delta_su2': '-0.00229(17)',
#                'fit': '1.1739(17)',
#                'logGBF': 58.416799301661065,
#                'name': 'xpt_FKFK_nnlo',
#                'vol corr': 0L}),
#              ('xpt_FKFK_nnlo_FV',
#               {'A_a': '-4.43(52)',
#                'A_k': '4.3(3.0)',
#                'A_loga': nan,
#                'A_p': '0.05(95)',
#                'L_4': nan,
#                'L_5': '-0.00053(58)',
#                'Q': 0.3280408029032321,
#                'Unnamed: 0': 52L,
#                'chi2/df': 1.1205944298857833,
#                'delta_su2': '-0.00229(17)',
#                'fit': '1.1740(17)',
#                'logGBF': 64.36108214483798,
#                'name': 'xpt_FKFK_nnlo_FV',
#                'vol corr': 10L}),
#              ('xpt_FKFK_nnlo_FV_alphaS',
#               {'A_a': '-3.6(2.8)',
#                'A_k': '4.4(3.0)',
#                'A_loga': '-1.3(4.2)',
#                'A_p': '0.02(96)',
#                'L_4': nan,
#                'L_5': '-0.00056(59)',
#                'Q': 0.3340624048269181,
#                'Unnamed: 0': 54L,
#                'chi2/df': 1.1142524218150458,
#                'delta_su2': '-0.00227(19)',
#                'fit': '1.1733(29)',
#                'logGBF': 64.22377055369813,
#                'name': 'xpt_FKFK_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('xpt_FKFK_nnlo_FV_alphaS_logSq',
#               {'A_a': '-3.6(2.8)',
#                'A_k': '4.1(3.0)',
#                'A_loga': '-1.3(4.2)',
#                'A_p': '0.17(96)',
#                'L_4': nan,
#                'L_5': '-0.00095(59)',
#                'Q': 0.5153661592308942,
#                'Unnamed: 0': 55L,
#                'chi2/df': 0.9454298514340852,
#                'delta_su2': '-0.00233(19)',
#                'fit': '1.1755(29)',
#                'logGBF': 65.55424917524252,
#                'name': 'xpt_FKFK_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('xpt_FKFK_nnlo_FV_logSq',
#               {'A_a': '-4.48(52)',
#                'A_k': '4.0(3.0)',
#                'A_loga': nan,
#                'A_p': '0.20(96)',
#                'L_4': nan,
#                'L_5': '-0.00092(58)',
#                'Q': 0.5079535466704809,
#                'Unnamed: 0': 53L,
#                'chi2/df': 0.9517960910832892,
#                'delta_su2': '-0.00235(18)',
#                'fit': '1.1762(17)',
#                'logGBF': 65.69147279304008,
#                'name': 'xpt_FKFK_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('xpt_FKFK_nnlo_alphaS',
#               {'A_a': '-3.4(2.8)',
#                'A_k': '4.9(3.0)',
#                'A_loga': '-1.2(4.2)',
#                'A_p': '-0.11(96)',
#                'L_4': nan,
#                'L_5': '-0.00066(59)',
#                'Q': 0.019684864317823087,
#                'Unnamed: 0': 50L,
#                'chi2/df': 1.8555452871745333,
#                'delta_su2': '-0.00227(19)',
#                'fit': '1.1732(29)',
#                'logGBF': 58.26829633485254,
#                'name': 'xpt_FKFK_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('xpt_FKFK_nnlo_alphaS_logSq',
#               {'A_a': '-3.4(2.8)',
#                'A_k': '4.8(3.0)',
#                'A_loga': '-1.2(4.2)',
#                'A_p': '-0.03(97)',
#                'L_4': nan,
#                'L_5': '-0.00109(59)',
#                'Q': 0.010402831303416831,
#                'Unnamed: 0': 51L,
#                'chi2/df': 1.9917492554403429,
#                'delta_su2': '-0.00233(19)',
#                'fit': '1.1754(29)',
#                'logGBF': 57.147509173923815,
#                'name': 'xpt_FKFK_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('xpt_FKFK_nnlo_logSq',
#               {'A_a': '-4.22(52)',
#                'A_k': '4.8(3.0)',
#                'A_loga': nan,
#                'A_p': '-0.003(964)',
#                'L_4': nan,
#                'L_5': '-0.00107(58)',
#                'Q': 0.01015078775782168,
#                'Unnamed: 0': 49L,
#                'chi2/df': 1.9968728348953808,
#                'delta_su2': '-0.00235(18)',
#                'fit': '1.1761(17)',
#                'logGBF': 57.294630403878664,
#                'name': 'xpt_FKFK_nnlo_logSq',
#                'vol corr': 0L}),
#              ('xpt_FKFpi_nnlo',
#               {'A_a': '-3.36(36)',
#                'A_k': '2.6(2.1)',
#                'A_loga': nan,
#                'A_p': '1.57(39)',
#                'L_4': nan,
#                'L_5': '-0.00043(49)',
#                'Q': 0.008083022031534623,
#                'Unnamed: 0': 56L,
#                'chi2/df': 2.044094757851486,
#                'delta_su2': '-0.00193(16)',
#                'fit': '1.1796(26)',
#                'logGBF': 57.3481041033899,
#                'name': 'xpt_FKFpi_nnlo',
#                'vol corr': 0L}),
#              ('xpt_FKFpi_nnlo_FV',
#               {'A_a': '-3.89(36)',
#                'A_k': '3.6(2.1)',
#                'A_loga': nan,
#                'A_p': '1.34(39)',
#                'L_4': nan,
#                'L_5': '-0.00066(49)',
#                'Q': 0.4382202443799999,
#                'Unnamed: 0': 60L,
#                'chi2/df': 1.0132908302106147,
#                'delta_su2': '-0.00196(17)',
#                'fit': '1.1806(28)',
#                'logGBF': 65.72068263481785,
#                'name': 'xpt_FKFpi_nnlo_FV',
#                'vol corr': 10L}),
#              ('xpt_FKFpi_nnlo_FV_alphaS',
#               {'A_a': '-3.3(2.8)',
#                'A_k': '3.7(2.1)',
#                'A_loga': '-0.9(4.2)',
#                'A_p': '1.33(39)',
#                'L_4': nan,
#                'L_5': '-0.00068(50)',
#                'Q': 0.4413785569591657,
#                'Unnamed: 0': 62L,
#                'chi2/df': 1.0104274112451064,
#                'delta_su2': '-0.00194(18)',
#                'fit': '1.1800(39)',
#                'logGBF': 65.56329274229677,
#                'name': 'xpt_FKFpi_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('xpt_FKFpi_nnlo_FV_alphaS_logSq',
#               {'A_a': '-3.3(2.8)',
#                'A_k': '2.2(2.1)',
#                'A_loga': '-0.7(4.2)',
#                'A_p': '1.86(39)',
#                'L_4': nan,
#                'L_5': '-0.00080(50)',
#                'Q': 0.3229566693144862,
#                'Unnamed: 0': 63L,
#                'chi2/df': 1.1260044898789094,
#                'delta_su2': '-0.00202(19)',
#                'fit': '1.1828(38)',
#                'logGBF': 64.50766764581877,
#                'name': 'xpt_FKFpi_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('xpt_FKFpi_nnlo_FV_logSq',
#               {'A_a': '-3.76(36)',
#                'A_k': '2.1(2.1)',
#                'A_loga': nan,
#                'A_p': '1.86(39)',
#                'L_4': nan,
#                'L_5': '-0.00079(49)',
#                'Q': 0.32145196816984417,
#                'Unnamed: 0': 61L,
#                'chi2/df': 1.1276156738691896,
#                'delta_su2': '-0.00203(17)',
#                'fit': '1.1832(27)',
#                'logGBF': 64.67625684163067,
#                'name': 'xpt_FKFpi_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('xpt_FKFpi_nnlo_alphaS',
#               {'A_a': '-3.0(2.8)',
#                'A_k': '2.6(2.1)',
#                'A_loga': '-0.5(4.2)',
#                'A_p': '1.56(39)',
#                'L_4': nan,
#                'L_5': '-0.00044(50)',
#                'Q': 0.00811831309546876,
#                'Unnamed: 0': 58L,
#                'chi2/df': 2.04319755801775,
#                'delta_su2': '-0.00192(18)',
#                'fit': '1.1792(38)',
#                'logGBF': 57.17279230340504,
#                'name': 'xpt_FKFpi_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('xpt_FKFpi_nnlo_alphaS_logSq',
#               {'A_a': '-3.0(2.8)',
#                'A_k': '0.5(2.1)',
#                'A_loga': '-0.2(4.2)',
#                'A_p': '2.20(40)',
#                'L_4': nan,
#                'L_5': '-0.00042(50)',
#                'Q': 0.00033064681865144197,
#                'Unnamed: 0': 59L,
#                'chi2/df': 2.657104060769937,
#                'delta_su2': '-0.00199(18)',
#                'fit': '1.1817(36)',
#                'logGBF': 52.038310261103476,
#                'name': 'xpt_FKFpi_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('xpt_FKFpi_nnlo_logSq',
#               {'A_a': '-3.14(36)',
#                'A_k': '0.5(2.1)',
#                'A_loga': nan,
#                'A_p': '2.20(40)',
#                'L_4': nan,
#                'L_5': '-0.00041(50)',
#                'Q': 0.0003304164908617893,
#                'Unnamed: 0': 57L,
#                'chi2/df': 2.6572302636086556,
#                'delta_su2': '-0.00200(17)',
#                'fit': '1.1819(24)',
#                'logGBF': 52.22167752292682,
#                'name': 'xpt_FKFpi_nnlo_logSq',
#                'vol corr': 0L}),
#              ('xpt_FpiFpi_nnlo',
#               {'A_a': '-2.71(24)',
#                'A_k': '0.7(1.4)',
#                'A_loga': nan,
#                'A_p': '2.30(12)',
#                'L_4': nan,
#                'L_5': '-0.00013(40)',
#                'Q': 0.0033596326483076307,
#                'Unnamed: 0': 64L,
#                'chi2/df': 2.2206986586515565,
#                'delta_su2': '-0.00139(17)',
#                'fit': '1.1825(34)',
#                'logGBF': 55.54736020163593,
#                'name': 'xpt_FpiFpi_nnlo',
#                'vol corr': 0L}),
#              ('xpt_FpiFpi_nnlo_FV',
#               {'A_a': '-3.28(23)',
#                'A_k': '2.3(1.4)',
#                'A_loga': nan,
#                'A_p': '2.21(11)',
#                'L_4': nan,
#                'L_5': '-0.00055(38)',
#                'Q': 0.41929052351011903,
#                'Unnamed: 0': 68L,
#                'chi2/df': 1.0306490252830318,
#                'delta_su2': '-0.00147(19)',
#                'fit': '1.1854(43)',
#                'logGBF': 65.73978163555475,
#                'name': 'xpt_FpiFpi_nnlo_FV',
#                'vol corr': 10L}),
#              ('xpt_FpiFpi_nnlo_FV_alphaS',
#               {'A_a': '-3.1(2.8)',
#                'A_k': '2.3(1.4)',
#                'A_loga': '-0.3(4.1)',
#                'A_p': '2.21(11)',
#                'L_4': nan,
#                'L_5': '-0.00055(38)',
#                'Q': 0.4195630188038451,
#                'Unnamed: 0': 70L,
#                'chi2/df': 1.0303966369014053,
#                'delta_su2': '-0.00147(21)',
#                'fit': '1.1852(54)',
#                'logGBF': 65.55613432629238,
#                'name': 'xpt_FpiFpi_nnlo_FV_alphaS',
#                'vol corr': 10L}),
#              ('xpt_FpiFpi_nnlo_FV_alphaS_logSq',
#               {'A_a': '-3.2(2.8)',
#                'A_k': '-0.3(1.5)',
#                'A_loga': '0.2(4.1)',
#                'A_p': '2.69(12)',
#                'L_4': nan,
#                'L_5': '-0.00033(41)',
#                'Q': 0.09715173013072087,
#                'Unnamed: 0': 71L,
#                'chi2/df': 1.4788733218927128,
#                'delta_su2': '-0.00152(20)',
#                'fit': '1.1870(46)',
#                'logGBF': 60.97995355536325,
#                'name': 'xpt_FpiFpi_nnlo_FV_alphaS_logSq',
#                'vol corr': 10L}),
#              ('xpt_FpiFpi_nnlo_FV_logSq',
#               {'A_a': '-3.04(25)',
#                'A_k': '-0.3(1.5)',
#                'A_loga': nan,
#                'A_p': '2.69(12)',
#                'L_4': nan,
#                'L_5': '-0.00033(40)',
#                'Q': 0.09709737564307767,
#                'Unnamed: 0': 69L,
#                'chi2/df': 1.4790184208649928,
#                'delta_su2': '-0.00152(17)',
#                'fit': '1.1868(33)',
#                'logGBF': 61.169133315725965,
#                'name': 'xpt_FpiFpi_nnlo_FV_logSq',
#                'vol corr': 10L}),
#              ('xpt_FpiFpi_nnlo_alphaS',
#               {'A_a': '-2.9(2.8)',
#                'A_k': '0.7(1.4)',
#                'A_loga': '0.2(4.1)',
#                'A_p': '2.30(12)',
#                'L_4': nan,
#                'L_5': '-0.00013(40)',
#                'Q': 0.0033625438764758172,
#                'Unnamed: 0': 66L,
#                'chi2/df': 2.2205281771010945,
#                'delta_su2': '-0.00140(19)',
#                'fit': '1.1827(47)',
#                'logGBF': 55.3580095817085,
#                'name': 'xpt_FpiFpi_nnlo_alphaS',
#                'vol corr': 0L}),
#              ('xpt_FpiFpi_nnlo_alphaS_logSq',
#               {'A_a': '-2.8(2.8)',
#                'A_k': '-2.8(1.6)',
#                'A_loga': '0.7(4.1)',
#                'A_p': '2.78(13)',
#                'L_4': nan,
#                'L_5': '0.00035(45)',
#                'Q': 1.8971000077841683e-05,
#                'Unnamed: 0': 67L,
#                'chi2/df': 3.157198789834569,
#                'delta_su2': '-0.00141(19)',
#                'fit': '1.1832(44)',
#                'logGBF': 46.47543030406838,
#                'name': 'xpt_FpiFpi_nnlo_alphaS_logSq',
#                'vol corr': 0L}),
#              ('xpt_FpiFpi_nnlo_logSq',
#               {'A_a': '-2.35(27)',
#                'A_k': '-2.8(1.6)',
#                'A_loga': nan,
#                'A_p': '2.78(13)',
#                'L_4': nan,
#                'L_5': '0.00035(45)',
#                'Q': 1.8765248955430026e-05,
#                'Unnamed: 0': 65L,
#                'chi2/df': 3.1590501647956417,
#                'delta_su2': '-0.00140(16)',
#                'fit': '1.1827(29)',
#                'logGBF': 46.6540344399936,
#                'name': 'xpt_FpiFpi_nnlo_logSq',
#                'vol corr': 0L})])

# %%
temp_results = {model : fit_results[model] for model in fit_results.keys()}

# %%
temp_results = {}
for model in fit_results.keys():
    if '_FKFpi_' in model:
        temp_results[model] = fit_results[model]
        
temp_results = fit_results

# %%
import scipy.stats as stats

def bma(fit_results):
    # read Bayes Factors
    logGBF_list = [fit_results[model]['logGBF'] for model in fit_results.keys()]
    
    # initiate a bunch of parameters
    FK_per_Fpi = 0
    FK_per_Fpi_list = []
    FK_per_Fpi_dict = dict()
    
    # weights
    w_lst = []
    wd = dict()
    
    # p. dist. fcn
    pdf = 0
    pdfdict = dict()
    
    # c. dist. fcn.
    cdf = 0
    cdfdict = dict()
    
    
    # for plotting
    x = np.linspace(1.16,1.20,2000)
    
    for model in fit_results.keys():
        r = gv.gvar(fit_results[model]['fit'])
        FK_per_Fpi_dict[model] = r
        
        w = 1/sum(np.exp(np.array(logGBF_list)-fit_results[model]['logGBF']))
        sqrtw = np.sqrt(w) # sqrt scales the std dev correctly
        wd[model] = w
        w_lst.append(w)
        
        FK_per_Fpi += gv.gvar(w*r.mean,sqrtw*r.sdev)
        FK_per_Fpi_list.append(r.mean)
        
        p = stats.norm.pdf(x,r.mean,r.sdev)
        pdf += w*p
        pdfdict[model] = w*p
        
        
        c = stats.norm.cdf(x,r.mean,r.sdev)
        cdf += w*c
        cdfdict[model] = w*c
        
    FK_per_Fpi_list = np.array(FK_per_Fpi_list)
    w_lst = np.array(w_lst)
    
    plot_params = {'x':x, 'pdf':pdf, 'pdfdict':pdfdict, 'cdf':cdf, 'cdfdict':cdfdict}
    return plot_params

params = bma(temp_results)

# %%
def plot_histogram(fit_results, plot_params):
    gr = 1.618034333
    fs2_base = 3.50394
    plt_axes = [0.14,0.165,0.825,0.825]
    fig_size2 = (fs2_base,fs2_base/gr)
    lw = 0.5
    fs_l = 15
    fs_xy = 24
    ts = 15

    x = plot_params['x']
    ysum = plot_params['pdf']

    ydict = plot_params['pdfdict']
    cdf = plot_params['cdf']

    # '-','--','-.',':'
    # #ec5d57 #70bf41 #51a7f9

    fig = plt.figure('result histogram')#,figsize=fig_size2)
    ax = plt.axes(plt_axes)
    ax.fill_between(x=x,y1=ysum,facecolor='#b36ae2',edgecolor='black',alpha=0.4,label='model average')
    # get 95% confidence
    lidx95 = abs(cdf-0.025).argmin()
    uidx95 = abs(cdf-0.975).argmin()
    ax.fill_between(x=x[lidx95:uidx95],y1=ysum[lidx95:uidx95],facecolor='#b36ae2',edgecolor='black',alpha=0.4)
    # get 68% confidence
    lidx68 = abs(cdf-0.158655254).argmin()
    uidx68 = abs(cdf-0.841344746).argmin()
    ax.fill_between(x=x[lidx68:uidx68],y1=ysum[lidx68:uidx68],facecolor='#b36ae2',edgecolor='black',alpha=0.4)
    # plot black curve over
    ax.errorbar(x=[x[lidx95],x[lidx95]],y=[0,ysum[lidx95]],color='black',lw=lw)
    ax.errorbar(x=[x[uidx95],x[uidx95]],y=[0,ysum[uidx95]],color='black',lw=lw)
    ax.errorbar(x=[x[lidx68],x[lidx68]],y=[0,ysum[lidx68]],color='black',lw=lw)
    ax.errorbar(x=[x[uidx68],x[uidx68]],y=[0,ysum[uidx68]],color='black',lw=lw)

    ax.errorbar(x=x,y=ysum,ls='-',color='black',lw=lw)

    for a in ydict.keys():
        ax.plot(x,ydict[a])

    leg = ax.legend(fontsize=fs_l, edgecolor='k',fancybox=False)
    ax.set_ylim(bottom=0)
    #ax.set_xlim([1.225,1.335])
    ax.set_xlabel('$F_K/F_\pi$', fontsize=fs_xy)
    frame = plt.gca()
    frame.axes.get_yaxis().set_visible(False)
    ax.xaxis.set_tick_params(labelsize=ts,width=lw)

    # legend line width
    [ax.spines[key].set_linewidth(lw) for key in ax.spines]
    leg.get_frame().set_linewidth(lw)


    #plt.show()
    plt.close()


plot_histogram(temp_results, params)
